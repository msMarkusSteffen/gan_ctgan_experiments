# %%
import seaborn as sns
import pandas as pd
import numpy as np

df = pd.read_csv("penguins_fake_real.CSV")
df.head()
# Out:
#    Unnamed: 0    species     island  culmen_length_mm  culmen_depth_mm  \
# 0           0     Adelie      Dream              39.5             16.7
# 1           1     Gentoo     Biscoe              46.9             14.6
# 2           2     Adelie  Torgersen              42.1             19.1
# 3           3  Chinstrap      Dream              49.8             17.3
# 4           4     Adelie     Biscoe              41.1             18.2
#
#    flipper_length_mm  body_mass_g     sex source
# 0              178.0       3250.0  FEMALE   real
# 1              222.0       4875.0  FEMALE   real
# 2              195.0       4000.0    MALE   real
# 3              198.0       3675.0  FEMALE   real
# 4              192.0       4050.0    MALE   real

# %%
sns.scatterplot(data=df, x="culmen_length_mm", y="flipper_length_mm", hue="species", style="source")
# Out:
# <AxesSubplot:xlabel='culmen_length_mm', ylabel='flipper_length_mm'>
