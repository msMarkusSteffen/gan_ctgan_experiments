# %% [markdown]
# # Example GAN with the overall loved Iris Flowers ;)
#
# # references
# https://de.wikipedia.org/wiki/Wasserstein-Metrik

# %%
from sklearn.datasets import load_iris
import torch

# %%
noise_vect = torch.rand(42)

# %% [markdown]
# noise_vect = torch.rand(42)
